# %%
import requests

# %%
result = requests.get(
    'https://www.slideshare.net/pantanwalahusain/anatomy-of-cornea-57446234?from_search=1')

# %%
result.text
# Out:
# '<!DOCTYPE html><html lang="en"><script id="gtm" defer="">\n          performance.mark(\'gtm.start\');\n          (function (w, d, s, l, i) {\n            w[l] = w[l] || [];\n            w[l].push({ \'gtm.start\': new Date().getTime(), event: \'gtm.js\' });\n            var f = d.getElementsByTagName(s)[0],\n                j = d.createElement(s),\n                dl = l != \'dataLayer\' ? \'&l=\' + l : \'\';\n            j.async = true;\n            j.src = \'https://www.googletagmanager.com/gtm.js?id=\' + i + dl;\n            j.onload = function () {\n              performance.mark(\'gtm.end\');\n              performance.measure(\'gtm\', \'gtm.start\', \'gtm.end\');\n            };\n            f.parentNode.insertBefore(j, f);\n        })(window, document, \'script\', \'dataLayer\', GTM-M36RG8PT);\n        </script><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1.0"/><link rel="shortcut icon" href="https://public.slidesharecdn.com/_ne
# ...

# %%
N = 1024
n = 1024

expected_picks = sum(1/i for i in range(N, n-1, -1))
expected_picks *= N

print(expected_picks)
# Out:
# 1.0

# %%
# Out:
# 0 4
# 0 12
# 16 16
# 1 40
# 96 96
# 112 112
# 192 192
# 1 240
# 256 256
# 352 352
# 448 448
# 576 576
# 640 640
# 1 672
# 768 768
# 928 928
# 1152 1152
# 1 1216
# 1 1408
# 1600 1600
# 2112 2112
# 2688 2688
# 1 2752
# 1 3136
# 1 3328
# 1 3456
# 4480 4480
# 1 4992
# 1 6528
# 7296 7296
# 1 7680
# 7936 7936
# 1 9472
# 9600 9600
# 9856 9856

# %%
96/32
# Out:
# 3.0
