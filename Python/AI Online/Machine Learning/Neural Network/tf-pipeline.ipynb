# %%
import tensorflow as tf

# %%
daily_sales = [21, 22, -108, 31, -1, 32, 34, 31]

# %%
tf_dataset = tf.data.Dataset.from_tensor_slices(daily_sales)
tf_dataset

# %%
for sales in tf_dataset.as_numpy_iterator():
    print(sales)

# %%
for sales in tf_dataset.take(3):
    print(sales.numpy())

# %%
tf_dataset = tf_dataset.filter(lambda x: x>=0)
for sales in tf_dataset:
    print(sales.numpy())

# %%
tf_dataset = tf_dataset.map(lambda x: x*72)
for sales in tf_dataset:
    print(sales.numpy())

# %%
tf_dataset = tf_dataset.shuffle(3)
for sales in tf_dataset:
    print(sales.numpy())

# %%
for sales in tf_dataset.batch(1):
    print(sales.numpy())

# %%
tf_dataset = tf.data.Dataset.from_tensor_slices(daily_sales)
tf_dataset

# %%
tf_dataset = tf_dataset.filter(lambda x: x>=0).map(lambda x: x*72).shuffle(2).batch(2)

for sales in tf_dataset:
    print(sales.numpy())

# %%
image_ds = tf.data.Dataset.list_files('../input/dogs-cats-images/dataset/training_set/*/*', shuffle=False)

for file in image_ds.take(5):
    print(file.numpy())

# %%
image_ds = image_ds.shuffle(200)

for file in image_ds.take(5):
    print(file.numpy())

# %%
classes = ["cats", "dogs"]

# %%
image_count = len(image_ds)
image_count

# %%
test_ds = tf.data.Dataset.list_files('../input/dogs-cats-images/dataset/test_set/*/*', shuffle=False)
test_ds = image_ds.shuffle(200)

# %%
import os
def get_label(file_path):
    return tf.strings.split(file_path, os.path.sep)[-2]

# %%
def process_img(file_path):
    label = get_label(file_path)
    
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img)
    img = tf.image.resize(img, (128, 128))
    
    return img, label

# %%
image_ds = image_ds.map(process_img)
for img, label in image_ds.take(3):
    print("Image", img)
    print("Label", label)

# %%
def scale(img, label):
    return img/255.0, label

# %%
image_ds = image_ds.map(scale)
for img, label in image_ds.take(3):
    print(img.numpy())
    print(label.numpy())
